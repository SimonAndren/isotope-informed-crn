# %% [markdown]
# # RPFR 3D Visualization
#
# Interactive 3D visualization of per-atom RPFR values using **RDKit** (molecule structure) and **py3Dmol** (3D rendering).
#
# **Test molecule:** Methyl carbamate — `COC(=O)NC(N)=O`
# Contains C, H, N, and O atoms → good demonstration of the cross-element scale problem.
#
# ---
# ### The cross-element RPFR problem
#
# RPFR values are **not comparable across elements**:
#
# | Element | Typical RPFR at 300 K |
# |---------|----------------------|
# | H | 10 – 15 |
# | C | 1.10 – 1.25 |
# | N | 1.05 – 1.15 |
# | O | 1.08 – 1.15 |
#
# Hydrogen exchange involves a much larger mass ratio (²H/¹H ≈ 2) compared to heavy-atom isotopes (¹³C/¹²C ≈ 1.08), so H RPFR is physically on a different scale.
#
# This notebook demonstrates four visualization strategies to handle this.

# %%
import sys
from pathlib import Path
import numpy as np
import h5py

# Path setup
project_root = Path.cwd().parent.parent
sys.path.insert(0, str(project_root / 'src'))

from rpfr_gui.data import ChemistryResolver, H5Provider
from rpfr_gui.domain import IsotopeGraph
from rpfr_gui.ui import RPFRVisualizer

H5_PATH  = Path('/Users/simonandren/QM9_H5/qm9s.h5')
IDX_PATH = project_root / 'data/processed/index.parquet'

print('Libraries loaded OK')
# Out:
# Libraries loaded OK

# %% [markdown]
# ## 1. Load the test molecule

# %%
SMILES = 'COC(=O)NC(N)=O'   # Methyl carbamate
TEMPERATURE = 300.0

resolver = ChemistryResolver(IDX_PATH)
provider = H5Provider(H5_PATH)

mol_id = resolver.resolve(SMILES, id_type='smiles')
print(f'Molecule ID: {mol_id}')

# Load per-atom data from HDF5 (DFT-optimised coords + RPFR)
with h5py.File(H5_PATH, 'r') as f:
    g = f[mol_id]
    symbols = [s.decode() for s in g['Atom_Symbol'][()]]
    coords  = np.stack([g['x'][()], g['y'][()], g['z'][()]], axis=1)
    rpfr    = g[f'RPFR_{int(TEMPERATURE)}K'][()]

import pandas as pd
df = pd.DataFrame({'atom': symbols, 'x': coords[:,0], 'y': coords[:,1], 'z': coords[:,2], 'RPFR': rpfr})
print(f'\n{len(df)} atoms loaded')
print(df.groupby('atom')['RPFR'].describe().round(5))
# Out:
# Molecule ID: 005752
#
# 14 atoms loaded
#       count      mean      std       min       25%       50%       75%  \
# atom
# C       3.0   1.18068  0.03514   1.14014   1.16988   1.19962   1.20095
# H       6.0  14.17134  1.02189  13.19008  13.35903  13.92393  14.78134
# N       2.0   1.10352  0.01264   1.09458   1.09905   1.10352   1.10799
# O       3.0   1.12027  0.00573   1.11567   1.11707   1.11847   1.12258
#
#            max
# atom
# C      1.20229
# H     15.75225
# N      1.11246
# O      1.12669

# %% [markdown]
# ## 2. Element-constrained normalization
#
# Isotope exchange only occurs within the same element (C↔C, H↔H, etc.).
# Setting a **carbon** anchor and asking for **hydrogen** relative RPFR is physically undefined — the code now returns `NaN` for cross-element queries.

# %%
rpfr_df = provider.get_rpfr(mol_id, temperature=TEMPERATURE)

graph = IsotopeGraph(connectivity='full')
nodes = graph.add_molecule(mol_id, rpfr_df)
graph.set_connectivity(mode='full')

# Set the carbonyl carbon (atom 2, C in C=O of ester) as anchor
c_nodes = [n for n in nodes if graph.graph.nodes[n]['atom_symbol'] == 'C']
graph.set_anchor(c_nodes[0])
print(f'Anchor: {c_nodes[0]}  element: {graph.anchor_element}')

df_rel = graph.get_rpfr_dataframe(relative=True)
print('\nRelative RPFR (NaN = different element from anchor):')
display(df_rel[['atom_symbol','rpfr' if 'rpfr' in df_rel.columns else 'relative_rpfr']]
        .rename(columns={'relative_rpfr': 'rel_rpfr'}))
# Out:
# Anchor: 005752_0  element: C
#
# Relative RPFR (NaN = different element from anchor):
#    atom_symbol  rel_rpfr
# 0            C  1.000000
# 1            O       NaN
# 2            C  1.054513
# 3            O       NaN
# 4            N       NaN
# 5            C  1.052171
# 6            N       NaN
# 7            O       NaN
# 8            H       NaN
# 9            H       NaN
# 10           H       NaN
# 11           H       NaN
# 12           H       NaN
# 13           H       NaN

# %%
# Per-element normalized view (minmax)
df_norm = graph.get_element_normalized_rpfr(method='minmax')
print('Minmax per element (0 = lowest in element, 1 = highest in element):')
display(df_norm[['node_id', 'atom_symbol', 'rpfr', 'element_mean', 'normalized_rpfr']].round(4))
# Out:
# Minmax per element (0 = lowest in element, 1 = highest in element):
#       node_id atom_symbol     rpfr  element_mean  normalized_rpfr
# 0    005752_0           C   1.1401        1.1807           0.0000
# 1    005752_1           O   1.1267        1.1203           1.0000
# 2    005752_2           C   1.2023        1.1807           1.0000
# 3    005752_3           O   1.1185        1.1203           0.2544
# 4    005752_4           N   1.1125        1.1035           1.0000
# 5    005752_5           C   1.1996        1.1807           0.9570
# 6    005752_6           N   1.0946        1.1035           0.0000
# 7    005752_7           O   1.1157        1.1203           0.0000
# 8    005752_8           H  13.7154       14.1713           0.2050
# 9    005752_9           H  13.1901       14.1713           0.0000
# 10  005752_10           H  13.2402       14.1713           0.0196
# 11  005752_11           H  15.7523       14.1713           1.0000
# 12  005752_12           H  14.1324       14.1713           0.3678
# 13  005752_13           H  14.9976       14.1713           0.7055

# %% [markdown]
# ## 3. Build the visualizer
#
# All four modes use the **DFT-optimised 3D coordinates** from the HDF5 file (not a generated conformer).

# %%
viz = RPFRVisualizer(SMILES, symbols, coords, rpfr, temperature=TEMPERATURE)
print(f'Molecule: {SMILES}')
print(f'Atoms: {viz.n_atoms}  |  Elements: {viz._elements}  |  T = {TEMPERATURE:.0f} K')
print()
display(viz.summary_table().round(4))
# Out:
# Molecule: COC(=O)NC(N)=O
# Atoms: 14  |  Elements: ['C', 'H', 'N', 'O']  |  T = 300 K
#     idx symbol     rpfr  el_mean   el_min   el_max  minmax
# 0     0      C   1.1401   1.1807   1.1401   1.2023  0.0000
# 1     1      O   1.1267   1.1203   1.1157   1.1267  1.0000
# 2     2      C   1.2023   1.1807   1.1401   1.2023  1.0000
# 3     3      O   1.1185   1.1203   1.1157   1.1267  0.2544
# 4     4      N   1.1125   1.1035   1.0946   1.1125  1.0000
# 5     5      C   1.1996   1.1807   1.1401   1.2023  0.9570
# 6     6      N   1.0946   1.1035   1.0946   1.1125  0.0000
# 7     7      O   1.1157   1.1203   1.1157   1.1267  0.0000
# 8     8      H  13.7154  14.1713  13.1901  15.7523  0.2050
# 9     9      H  13.1901  14.1713  13.1901  15.7523  0.0000
# 10   10      H  13.2402  14.1713  13.1901  15.7523  0.0196
# 11   11      H  15.7523  14.1713  13.1901  15.7523  1.0000
# 12   12      H  14.1324  14.1713  13.1901  15.7523  0.3678
# 13   13      H  14.9976  14.1713  13.1901  15.7523  0.7055

# %% [markdown]
# ## Mode 1 — Element filter
#
# **Scientifically strictest.** Display only atoms of one element at a time,
# coloured on their own min-max RPFR scale.
# Other atoms shown as faint grey sticks for structural context.
#
# Use this when you want to compare site-specific fractionation within one element.

# %%
# Hydrogen sites — largest absolute RPFR variation
viz.show_element_filter('C')
# Out:
# <div id="3dmolviewer_17707599702217422"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_17707599702217422" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17707599702217422 = null;
# var warn = document.getElementById("3dmolwarning_17707599702217422");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17707599702217422 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17707599702217422"),{backgroundColor:"white"});
# viewer_17707599702217422.zoomTo();
# 	viewer_17707599702217422.addModel("14\n\nC       0.156999      1.333185      0.009561\nO      -0.069606     -0.082102      0.122568\nC      -1.361814     -0.475720     -0.036519\nO      -2.284407      0.259775     -0.244541\nN      -1.389723     -1.860005      0.058545\nC      -2.547330     -2.657986      0.154573\nN      -2.243415     -4.001604      0.037110\nO      -3.655608     -2.237477      0.367345\nH       1.224605      1.467271      0.160637\nH      -0.136896      1.691054     -0.976945\nH      -0.406897      1.872839      0.769684\nH      -0.493480     -2.298399      0.206783\nH      -1.465963     -4.289907     -0.535549\nH      -3.051035     -4.603504      0.006490","xyz");
# 	viewer_17707599702217422.setStyle({},{"stick": {"radius": 0.06, "color": "lightgrey"}});
# 	viewer_17707599702217422.addSphere({"center": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "radius": 0.3, "color": "#f7fcf5", "opacity": 0.85});
# 	viewer_17707599702217422.addLabel("C0\n1.140",{"position": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_17707599702217422.addSphere({"center": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "radius": 0.3, "color": "#00441b", "opacity": 0.85});
# 	viewer_17707599702217422.addLabel("C2\n1.202",{"position": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_17707599702217422.addSphere({"center": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "radius": 0.3, "color": "#005120", "opacity": 0.85});
# 	viewer_17707599702217422.addLabel("C5\n1.200",{"position": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_17707599702217422.addLabel("C atoms  |  T=300K  |  RPFR [1.1401, 1.2023]",{"position": {"x": 0, "y": 0, "z": 0}, "fontSize": 12, "fontColor": "black", "backgroundColor": "white", "backgroundOpacity": 0.7, "screenOffset": {"x": 0, "y": -200}});
# 	viewer_17707599702217422.zoomTo();
# viewer_17707599702217422.render();
# });
# </script>

# %%
# Carbon sites
viz.show_element_filter('O')
# Out:
# <div id="3dmolviewer_1770759970230874"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_1770759970230874" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1770759970230874 = null;
# var warn = document.getElementById("3dmolwarning_1770759970230874");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1770759970230874 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1770759970230874"),{backgroundColor:"white"});
# viewer_1770759970230874.zoomTo();
# 	viewer_1770759970230874.addModel("14\n\nC       0.156999      1.333185      0.009561\nO      -0.069606     -0.082102      0.122568\nC      -1.361814     -0.475720     -0.036519\nO      -2.284407      0.259775     -0.244541\nN      -1.389723     -1.860005      0.058545\nC      -2.547330     -2.657986      0.154573\nN      -2.243415     -4.001604      0.037110\nO      -3.655608     -2.237477      0.367345\nH       1.224605      1.467271      0.160637\nH      -0.136896      1.691054     -0.976945\nH      -0.406897      1.872839      0.769684\nH      -0.493480     -2.298399      0.206783\nH      -1.465963     -4.289907     -0.535549\nH      -3.051035     -4.603504      0.006490","xyz");
# 	viewer_1770759970230874.setStyle({},{"stick": {"radius": 0.06, "color": "lightgrey"}});
# 	viewer_1770759970230874.addSphere({"center": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "radius": 0.3, "color": "#7f2704", "opacity": 0.85});
# 	viewer_1770759970230874.addLabel("O1\n1.127",{"position": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970230874.addSphere({"center": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "radius": 0.3, "color": "#fdcfa0", "opacity": 0.85});
# 	viewer_1770759970230874.addLabel("O3\n1.118",{"position": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970230874.addSphere({"center": {"x": -3.65560793876648, "y": -2.2374770641326904, "z": 0.3673450052738189}, "radius": 0.3, "color": "#fff5eb", "opacity": 0.85});
# 	viewer_1770759970230874.addLabel("O7\n1.116",{"position": {"x": -3.65560793876648, "y": -2.2374770641326904, "z": 0.3673450052738189}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970230874.addLabel("O atoms  |  T=300K  |  RPFR [1.1157, 1.1267]",{"position": {"x": 0, "y": 0, "z": 0}, "fontSize": 12, "fontColor": "black", "backgroundColor": "white", "backgroundOpacity": 0.7, "screenOffset": {"x": 0, "y": -200}});
# 	viewer_1770759970230874.zoomTo();
# viewer_1770759970230874.render();
# });
# </script>

# %%
# Oxygen sites
viz.show_element_filter('N')
# Out:
# <div id="3dmolviewer_17707599702412028"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_17707599702412028" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17707599702412028 = null;
# var warn = document.getElementById("3dmolwarning_17707599702412028");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17707599702412028 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17707599702412028"),{backgroundColor:"white"});
# viewer_17707599702412028.zoomTo();
# 	viewer_17707599702412028.addModel("14\n\nC       0.156999      1.333185      0.009561\nO      -0.069606     -0.082102      0.122568\nC      -1.361814     -0.475720     -0.036519\nO      -2.284407      0.259775     -0.244541\nN      -1.389723     -1.860005      0.058545\nC      -2.547330     -2.657986      0.154573\nN      -2.243415     -4.001604      0.037110\nO      -3.655608     -2.237477      0.367345\nH       1.224605      1.467271      0.160637\nH      -0.136896      1.691054     -0.976945\nH      -0.406897      1.872839      0.769684\nH      -0.493480     -2.298399      0.206783\nH      -1.465963     -4.289907     -0.535549\nH      -3.051035     -4.603504      0.006490","xyz");
# 	viewer_17707599702412028.setStyle({},{"stick": {"radius": 0.06, "color": "lightgrey"}});
# 	viewer_17707599702412028.addSphere({"center": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "radius": 0.3, "color": "#3f007d", "opacity": 0.85});
# 	viewer_17707599702412028.addLabel("N4\n1.112",{"position": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_17707599702412028.addSphere({"center": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "radius": 0.3, "color": "#fcfbfd", "opacity": 0.85});
# 	viewer_17707599702412028.addLabel("N6\n1.095",{"position": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_17707599702412028.addLabel("N atoms  |  T=300K  |  RPFR [1.0946, 1.1125]",{"position": {"x": 0, "y": 0, "z": 0}, "fontSize": 12, "fontColor": "black", "backgroundColor": "white", "backgroundOpacity": 0.7, "screenOffset": {"x": 0, "y": -200}});
# 	viewer_17707599702412028.zoomTo();
# viewer_17707599702412028.render();
# });
# </script>

# %% [markdown]
# ## Mode 2 — Multi-element (independent colour scales)
#
# All atoms shown simultaneously, each element with its own colormap:
# - **H** → Blues
# - **C** → Greens
# - **N** → Purples
# - **O** → Oranges
#
# Each element is independently min-max normalised so variation within each element is visible.
#
# **⚠️ Note:** Colours are NOT comparable across elements — a dark blue H is not the same fractionation level as a dark green C.

# %%
viz.show_multi_element()
# Out:
# <div id="3dmolviewer_1770759970256788"  style="position: relative; width: 800px; height: 550px;">
#         <p id="3dmolwarning_1770759970256788" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1770759970256788 = null;
# var warn = document.getElementById("3dmolwarning_1770759970256788");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1770759970256788 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1770759970256788"),{backgroundColor:"white"});
# viewer_1770759970256788.zoomTo();
# 	viewer_1770759970256788.addModel("14\n\nC       0.156999      1.333185      0.009561\nO      -0.069606     -0.082102      0.122568\nC      -1.361814     -0.475720     -0.036519\nO      -2.284407      0.259775     -0.244541\nN      -1.389723     -1.860005      0.058545\nC      -2.547330     -2.657986      0.154573\nN      -2.243415     -4.001604      0.037110\nO      -3.655608     -2.237477      0.367345\nH       1.224605      1.467271      0.160637\nH      -0.136896      1.691054     -0.976945\nH      -0.406897      1.872839      0.769684\nH      -0.493480     -2.298399      0.206783\nH      -1.465963     -4.289907     -0.535549\nH      -3.051035     -4.603504      0.006490","xyz");
# 	viewer_1770759970256788.setStyle({},{"stick": {"radius": 0.06, "color": "lightgrey"}});
# 	viewer_1770759970256788.addSphere({"center": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "radius": 0.28, "color": "#f7fcf5", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("C0\n1.140",{"position": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "radius": 0.28, "color": "#00441b", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("C2\n1.202",{"position": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "radius": 0.28, "color": "#005120", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("C5\n1.200",{"position": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": 1.2246049642562866, "y": 1.4672709703445435, "z": 0.1606370061635971}, "radius": 0.28, "color": "#cfe1f2", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("H8\n13.715",{"position": {"x": 1.2246049642562866, "y": 1.4672709703445435, "z": 0.1606370061635971}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -0.1368959993124008, "y": 1.6910539865493774, "z": -0.9769449830055236}, "radius": 0.28, "color": "#f7fbff", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("H9\n13.190",{"position": {"x": -0.1368959993124008, "y": 1.6910539865493774, "z": -0.9769449830055236}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -0.4068970084190368, "y": 1.8728389739990234, "z": 0.7696840167045593}, "radius": 0.28, "color": "#f3f8fe", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("H10\n13.240",{"position": {"x": -0.4068970084190368, "y": 1.8728389739990234, "z": 0.7696840167045593}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -0.4934799969196319, "y": -2.298398971557617, "z": 0.2067829966545105}, "radius": 0.28, "color": "#08306b", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("H11\n15.752",{"position": {"x": -0.4934799969196319, "y": -2.298398971557617, "z": 0.2067829966545105}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -1.4659630060195925, "y": -4.289906978607178, "z": -0.535548985004425}, "radius": 0.28, "color": "#a0cbe2", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("H12\n14.132",{"position": {"x": -1.4659630060195925, "y": -4.289906978607178, "z": -0.535548985004425}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -3.051034927368164, "y": -4.603504180908203, "z": 0.0064900000579655}, "radius": 0.28, "color": "#2d7dbb", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("H13\n14.998",{"position": {"x": -3.051034927368164, "y": -4.603504180908203, "z": 0.0064900000579655}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "radius": 0.28, "color": "#3f007d", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("N4\n1.112",{"position": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "radius": 0.28, "color": "#fcfbfd", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("N6\n1.095",{"position": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "radius": 0.28, "color": "#7f2704", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("O1\n1.127",{"position": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "radius": 0.28, "color": "#fdcfa0", "opacity": 0.85});
# 	viewer_1770759970256788.addLabel("O3\n1.118",{"position": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970256788.addSphere({"center": {"x": -3.65560

# %% [markdown]
# ## Mode 3 — Global log scale
#
# All atoms on one shared colour scale using **log₁₀(RPFR)**.
# Log scale is essential here — without it, H atoms dominate and all heavy atoms look the same.
#
# The H atoms will still appear at the yellow/bright end and C/N/O at the blue/dark end,
# but internal variation within both groups becomes visible.
#
# Use this for a raw first look at the full dataset.

# %%
viz.show_global_scale(log_scale=True)
# Out:
# <div id="3dmolviewer_1770759970267736"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_1770759970267736" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1770759970267736 = null;
# var warn = document.getElementById("3dmolwarning_1770759970267736");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1770759970267736 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1770759970267736"),{backgroundColor:"white"});
# viewer_1770759970267736.zoomTo();
# 	viewer_1770759970267736.addModel("14\n\nC       0.156999      1.333185      0.009561\nO      -0.069606     -0.082102      0.122568\nC      -1.361814     -0.475720     -0.036519\nO      -2.284407      0.259775     -0.244541\nN      -1.389723     -1.860005      0.058545\nC      -2.547330     -2.657986      0.154573\nN      -2.243415     -4.001604      0.037110\nO      -3.655608     -2.237477      0.367345\nH       1.224605      1.467271      0.160637\nH      -0.136896      1.691054     -0.976945\nH      -0.406897      1.872839      0.769684\nH      -0.493480     -2.298399      0.206783\nH      -1.465963     -4.289907     -0.535549\nH      -3.051035     -4.603504      0.006490","xyz");
# 	viewer_1770759970267736.setStyle({},{"stick": {"radius": 0.06, "color": "lightgrey"}});
# 	viewer_1770759970267736.addSphere({"center": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "radius": 0.28, "color": "#450559", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("C0\n1.140",{"position": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "radius": 0.28, "color": "#450457", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("O1\n1.127",{"position": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "radius": 0.28, "color": "#470e61", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("C2\n1.202",{"position": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "radius": 0.28, "color": "#450457", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("O3\n1.118",{"position": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "radius": 0.28, "color": "#440256", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("N4\n1.112",{"position": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "radius": 0.28, "color": "#470d60", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("C5\n1.200",{"position": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "radius": 0.28, "color": "#440154", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("N6\n1.095",{"position": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -3.65560793876648, "y": -2.2374770641326904, "z": 0.3673450052738189}, "radius": 0.28, "color": "#440256", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("O7\n1.116",{"position": {"x": -3.65560793876648, "y": -2.2374770641326904, "z": 0.3673450052738189}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": 1.2246049642562866, "y": 1.4672709703445435, "z": 0.1606370061635971}, "radius": 0.28, "color": "#dde318", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("H8\n13.715",{"position": {"x": 1.2246049642562866, "y": 1.4672709703445435, "z": 0.1606370061635971}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -0.1368959993124008, "y": 1.6910539865493774, "z": -0.9769449830055236}, "radius": 0.28, "color": "#d2e21b", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("H9\n13.190",{"position": {"x": -0.1368959993124008, "y": 1.6910539865493774, "z": -0.9769449830055236}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -0.4068970084190368, "y": 1.8728389739990234, "z": 0.7696840167045593}, "radius": 0.28, "color": "#d5e21a", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("H10\n13.240",{"position": {"x": -0.4068970084190368, "y": 1.8728389739990234, "z": 0.7696840167045593}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -0.4934799969196319, "y": -2.298398971557617, "z": 0.2067829966545105}, "radius": 0.28, "color": "#fde725", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("H11\n15.752",{"position": {"x": -0.4934799969196319, "y": -2.298398971557617, "z": 0.2067829966545105}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -1.4659630060195925, "y": -4.289906978607178, "z": -0.535548985004425}, "radius": 0.28, "color": "#e5e419", "opacity": 0.85});
# 	viewer_1770759970267736.addLabel("H12\n14.132",{"position": {"x": -1.4659630060195925, "y": -4.289906978607178, "z": -0.535548985004425}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970267736.addSphere({"center": {"x": -3.0510349

# %%
# Linear scale for comparison — heavy atoms become indistinguishable
viz.show_global_scale(log_scale=False, cmap='plasma')
# Out:
# <div id="3dmolviewer_1770759970279673"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_1770759970279673" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1770759970279673 = null;
# var warn = document.getElementById("3dmolwarning_1770759970279673");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1770759970279673 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1770759970279673"),{backgroundColor:"white"});
# viewer_1770759970279673.zoomTo();
# 	viewer_1770759970279673.addModel("14\n\nC       0.156999      1.333185      0.009561\nO      -0.069606     -0.082102      0.122568\nC      -1.361814     -0.475720     -0.036519\nO      -2.284407      0.259775     -0.244541\nN      -1.389723     -1.860005      0.058545\nC      -2.547330     -2.657986      0.154573\nN      -2.243415     -4.001604      0.037110\nO      -3.655608     -2.237477      0.367345\nH       1.224605      1.467271      0.160637\nH      -0.136896      1.691054     -0.976945\nH      -0.406897      1.872839      0.769684\nH      -0.493480     -2.298399      0.206783\nH      -1.465963     -4.289907     -0.535549\nH      -3.051035     -4.603504      0.006490","xyz");
# 	viewer_1770759970279673.setStyle({},{"stick": {"radius": 0.06, "color": "lightgrey"}});
# 	viewer_1770759970279673.addSphere({"center": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "radius": 0.28, "color": "#0d0887", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("C0\n1.140",{"position": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "radius": 0.28, "color": "#0d0887", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("O1\n1.127",{"position": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "radius": 0.28, "color": "#100788", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("C2\n1.202",{"position": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "radius": 0.28, "color": "#0d0887", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("O3\n1.118",{"position": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "radius": 0.28, "color": "#0d0887", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("N4\n1.112",{"position": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "radius": 0.28, "color": "#100788", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("C5\n1.200",{"position": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "radius": 0.28, "color": "#0d0887", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("N6\n1.095",{"position": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -3.65560793876648, "y": -2.2374770641326904, "z": 0.3673450052738189}, "radius": 0.28, "color": "#0d0887", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("O7\n1.116",{"position": {"x": -3.65560793876648, "y": -2.2374770641326904, "z": 0.3673450052738189}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": 1.2246049642562866, "y": 1.4672709703445435, "z": 0.1606370061635971}, "radius": 0.28, "color": "#febe2a", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("H8\n13.715",{"position": {"x": 1.2246049642562866, "y": 1.4672709703445435, "z": 0.1606370061635971}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -0.1368959993124008, "y": 1.6910539865493774, "z": -0.9769449830055236}, "radius": 0.28, "color": "#fdb130", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("H9\n13.190",{"position": {"x": -0.1368959993124008, "y": 1.6910539865493774, "z": -0.9769449830055236}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -0.4068970084190368, "y": 1.8728389739990234, "z": 0.7696840167045593}, "radius": 0.28, "color": "#fdb22f", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("H10\n13.240",{"position": {"x": -0.4068970084190368, "y": 1.8728389739990234, "z": 0.7696840167045593}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -0.4934799969196319, "y": -2.298398971557617, "z": 0.2067829966545105}, "radius": 0.28, "color": "#f0f921", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("H11\n15.752",{"position": {"x": -0.4934799969196319, "y": -2.298398971557617, "z": 0.2067829966545105}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -1.4659630060195925, "y": -4.289906978607178, "z": -0.535548985004425}, "radius": 0.28, "color": "#fdca26", "opacity": 0.85});
# 	viewer_1770759970279673.addLabel("H12\n14.132",{"position": {"x": -1.4659630060195925, "y": -4.289906978607178, "z": -0.535548985004425}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970279673.addSphere({"center": {"x": -3.0510349

# %% [markdown]
# ## Mode 3 — Global (log) scale
#
# **Useful for a raw overview of all elements at once.**
# Because H RPFR (~10–15) is ~10× larger than C/N/O (~1.1–1.2),
# a **log₁₀ scale** is strongly recommended so variation within heavy atoms is still visible.

# %%
viz.show_global_scale()
# Out:
# <div id="3dmolviewer_1770759970290325"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_1770759970290325" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1770759970290325 = null;
# var warn = document.getElementById("3dmolwarning_1770759970290325");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1770759970290325 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1770759970290325"),{backgroundColor:"white"});
# viewer_1770759970290325.zoomTo();
# 	viewer_1770759970290325.addModel("14\n\nC       0.156999      1.333185      0.009561\nO      -0.069606     -0.082102      0.122568\nC      -1.361814     -0.475720     -0.036519\nO      -2.284407      0.259775     -0.244541\nN      -1.389723     -1.860005      0.058545\nC      -2.547330     -2.657986      0.154573\nN      -2.243415     -4.001604      0.037110\nO      -3.655608     -2.237477      0.367345\nH       1.224605      1.467271      0.160637\nH      -0.136896      1.691054     -0.976945\nH      -0.406897      1.872839      0.769684\nH      -0.493480     -2.298399      0.206783\nH      -1.465963     -4.289907     -0.535549\nH      -3.051035     -4.603504      0.006490","xyz");
# 	viewer_1770759970290325.setStyle({},{"stick": {"radius": 0.06, "color": "lightgrey"}});
# 	viewer_1770759970290325.addSphere({"center": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "radius": 0.28, "color": "#450559", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("C0\n1.140",{"position": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "radius": 0.28, "color": "#450457", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("O1\n1.127",{"position": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "radius": 0.28, "color": "#470e61", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("C2\n1.202",{"position": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "radius": 0.28, "color": "#450457", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("O3\n1.118",{"position": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "radius": 0.28, "color": "#440256", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("N4\n1.112",{"position": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "radius": 0.28, "color": "#470d60", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("C5\n1.200",{"position": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "radius": 0.28, "color": "#440154", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("N6\n1.095",{"position": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -3.65560793876648, "y": -2.2374770641326904, "z": 0.3673450052738189}, "radius": 0.28, "color": "#440256", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("O7\n1.116",{"position": {"x": -3.65560793876648, "y": -2.2374770641326904, "z": 0.3673450052738189}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": 1.2246049642562866, "y": 1.4672709703445435, "z": 0.1606370061635971}, "radius": 0.28, "color": "#dde318", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("H8\n13.715",{"position": {"x": 1.2246049642562866, "y": 1.4672709703445435, "z": 0.1606370061635971}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -0.1368959993124008, "y": 1.6910539865493774, "z": -0.9769449830055236}, "radius": 0.28, "color": "#d2e21b", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("H9\n13.190",{"position": {"x": -0.1368959993124008, "y": 1.6910539865493774, "z": -0.9769449830055236}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -0.4068970084190368, "y": 1.8728389739990234, "z": 0.7696840167045593}, "radius": 0.28, "color": "#d5e21a", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("H10\n13.240",{"position": {"x": -0.4068970084190368, "y": 1.8728389739990234, "z": 0.7696840167045593}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -0.4934799969196319, "y": -2.298398971557617, "z": 0.2067829966545105}, "radius": 0.28, "color": "#fde725", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("H11\n15.752",{"position": {"x": -0.4934799969196319, "y": -2.298398971557617, "z": 0.2067829966545105}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -1.4659630060195925, "y": -4.289906978607178, "z": -0.535548985004425}, "radius": 0.28, "color": "#e5e419", "opacity": 0.85});
# 	viewer_1770759970290325.addLabel("H12\n14.132",{"position": {"x": -1.4659630060195925, "y": -4.289906978607178, "z": -0.535548985004425}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970290325.addSphere({"center": {"x": -3.0510349

# %%
# Linear scale (less useful — hydrogen dominates)
viz.show_global_scale(log_scale=False)
# Out:
# <div id="3dmolviewer_1770759970302478"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_1770759970302478" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1770759970302478 = null;
# var warn = document.getElementById("3dmolwarning_1770759970302478");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1770759970302478 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1770759970302478"),{backgroundColor:"white"});
# viewer_1770759970302478.zoomTo();
# 	viewer_1770759970302478.addModel("14\n\nC       0.156999      1.333185      0.009561\nO      -0.069606     -0.082102      0.122568\nC      -1.361814     -0.475720     -0.036519\nO      -2.284407      0.259775     -0.244541\nN      -1.389723     -1.860005      0.058545\nC      -2.547330     -2.657986      0.154573\nN      -2.243415     -4.001604      0.037110\nO      -3.655608     -2.237477      0.367345\nH       1.224605      1.467271      0.160637\nH      -0.136896      1.691054     -0.976945\nH      -0.406897      1.872839      0.769684\nH      -0.493480     -2.298399      0.206783\nH      -1.465963     -4.289907     -0.535549\nH      -3.051035     -4.603504      0.006490","xyz");
# 	viewer_1770759970302478.setStyle({},{"stick": {"radius": 0.06, "color": "lightgrey"}});
# 	viewer_1770759970302478.addSphere({"center": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "radius": 0.28, "color": "#440154", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("C0\n1.140",{"position": {"x": 0.1569990068674087, "y": 1.3331849575042725, "z": 0.0095610003918409}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "radius": 0.28, "color": "#440154", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("O1\n1.127",{"position": {"x": -0.0696059986948967, "y": -0.08210200071334839, "z": 0.1225679963827133}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "radius": 0.28, "color": "#440256", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("C2\n1.202",{"position": {"x": -1.361814022064209, "y": -0.47571998834609985, "z": -0.0365189984440803}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "radius": 0.28, "color": "#440154", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("O3\n1.118",{"position": {"x": -2.284406900405884, "y": 0.2597750127315521, "z": -0.2445410043001175}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "radius": 0.28, "color": "#440154", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("N4\n1.112",{"position": {"x": -1.3897229433059692, "y": -1.8600050210952759, "z": 0.0585450008511543}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "radius": 0.28, "color": "#440256", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("C5\n1.200",{"position": {"x": -2.547329902648926, "y": -2.6579859256744385, "z": 0.154572993516922}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "radius": 0.28, "color": "#440154", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("N6\n1.095",{"position": {"x": -2.243415117263794, "y": -4.001604080200195, "z": 0.0371100008487701}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -3.65560793876648, "y": -2.2374770641326904, "z": 0.3673450052738189}, "radius": 0.28, "color": "#440154", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("O7\n1.116",{"position": {"x": -3.65560793876648, "y": -2.2374770641326904, "z": 0.3673450052738189}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": 1.2246049642562866, "y": 1.4672709703445435, "z": 0.1606370061635971}, "radius": 0.28, "color": "#a2da37", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("H8\n13.715",{"position": {"x": 1.2246049642562866, "y": 1.4672709703445435, "z": 0.1606370061635971}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -0.1368959993124008, "y": 1.6910539865493774, "z": -0.9769449830055236}, "radius": 0.28, "color": "#8bd646", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("H9\n13.190",{"position": {"x": -0.1368959993124008, "y": 1.6910539865493774, "z": -0.9769449830055236}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -0.4068970084190368, "y": 1.8728389739990234, "z": 0.7696840167045593}, "radius": 0.28, "color": "#8ed645", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("H10\n13.240",{"position": {"x": -0.4068970084190368, "y": 1.8728389739990234, "z": 0.7696840167045593}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -0.4934799969196319, "y": -2.298398971557617, "z": 0.2067829966545105}, "radius": 0.28, "color": "#fde725", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("H11\n15.752",{"position": {"x": -0.4934799969196319, "y": -2.298398971557617, "z": 0.2067829966545105}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -1.4659630060195925, "y": -4.289906978607178, "z": -0.535548985004425}, "radius": 0.28, "color": "#b5de2b", "opacity": 0.85});
# 	viewer_1770759970302478.addLabel("H12\n14.132",{"position": {"x": -1.4659630060195925, "y": -4.289906978607178, "z": -0.535548985004425}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970302478.addSphere({"center": {"x": -3.0510349

# %% [markdown]
# ## 5. Compare molecules: benzene vs. methane

# %%
def load_and_visualize(smiles, temperature=300.0):
    """Helper: resolve, load, and return a RPFRVisualizer."""
    mol_id = resolver.resolve(smiles, id_type='smiles')
    if mol_id is None:
        print(f'Not found: {smiles}'); return None
    with h5py.File(H5_PATH, 'r') as f:
        g = f[mol_id]
        syms  = [s.decode() for s in g['Atom_Symbol'][()]]
        xyz   = np.stack([g['x'][()], g['y'][()], g['z'][()]], axis=1)
        rpfr  = g[f'RPFR_{int(temperature)}K'][()]
    print(f'{smiles} ({mol_id}) — {len(syms)} atoms')
    return RPFRVisualizer(smiles, syms, xyz, rpfr, temperature=temperature)

viz_benzene = load_and_visualize('c1ccccc1')
viz_methane = load_and_visualize('C')
# Out:
# c1ccccc1 (000197) — 12 atoms
# C (000001) — 5 atoms

# %%
print('Benzene — per-element minmax (all H are equivalent by symmetry):')
viz_benzene.show_multi_element()
# Out:
# Benzene — per-element minmax (all H are equivalent by symmetry):
# <div id="3dmolviewer_1770759970335668"  style="position: relative; width: 800px; height: 550px;">
#         <p id="3dmolwarning_1770759970335668" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1770759970335668 = null;
# var warn = document.getElementById("3dmolwarning_1770759970335668");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1770759970335668 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1770759970335668"),{backgroundColor:"white"});
# viewer_1770759970335668.zoomTo();
# 	viewer_1770759970335668.addModel("12\n\nC      -0.025035      1.382787      0.010386\nC       1.170803      2.095092      0.002297\nC       2.385527      1.415605     -0.013142\nC       2.404402      0.023821     -0.020484\nC       1.208563     -0.688484     -0.012405\nC      -0.006160     -0.008999      0.003031\nH      -0.970435      1.911634      0.022398\nH       1.156096      3.178306      0.008011\nH       3.316226      1.970005     -0.019434\nH       3.349802     -0.505027     -0.032480\nH       1.223273     -1.771699     -0.018125\nH      -0.936860     -0.563396      0.009312","xyz");
# 	viewer_1770759970335668.setStyle({},{"stick": {"radius": 0.06, "color": "lightgrey"}});
# 	viewer_1770759970335668.addSphere({"center": {"x": -0.025034999474883, "y": 1.3827869892120361, "z": 0.0103860003873705}, "radius": 0.28, "color": "#00451c", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("C0\n1.157",{"position": {"x": -0.025034999474883, "y": 1.3827869892120361, "z": 0.0103860003873705}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addSphere({"center": {"x": 1.1708029508590698, "y": 2.0950920581817627, "z": 0.0022970000281929}, "radius": 0.28, "color": "#f1faee", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("C1\n1.157",{"position": {"x": 1.1708029508590698, "y": 2.0950920581817627, "z": 0.0022970000281929}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addSphere({"center": {"x": 2.3855268955230717, "y": 1.4156049489974976, "z": -0.013141999952495}, "radius": 0.28, "color": "#bce4b5", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("C2\n1.157",{"position": {"x": 2.3855268955230717, "y": 1.4156049489974976, "z": -0.013141999952495}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addSphere({"center": {"x": 2.404402017593384, "y": 0.023821000009775162, "z": -0.0204840004444122}, "radius": 0.28, "color": "#00441b", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("C3\n1.157",{"position": {"x": 2.404402017593384, "y": 0.023821000009775162, "z": -0.0204840004444122}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addSphere({"center": {"x": 1.208562970161438, "y": -0.6884840130805969, "z": -0.0124049996957182}, "radius": 0.28, "color": "#f7fcf5", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("C4\n1.157",{"position": {"x": 1.208562970161438, "y": -0.6884840130805969, "z": -0.0124049996957182}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addSphere({"center": {"x": -0.0061599998734891, "y": -0.008999000303447247, "z": 0.0030310000292956}, "radius": 0.28, "color": "#cbeac4", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("C5\n1.157",{"position": {"x": -0.0061599998734891, "y": -0.008999000303447247, "z": 0.0030310000292956}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addSphere({"center": {"x": -0.9704350233078004, "y": 1.9116339683532715, "z": 0.0223980005830526}, "radius": 0.28, "color": "#4e9acb", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("H6\n12.465",{"position": {"x": -0.9704350233078004, "y": 1.9116339683532715, "z": 0.0223980005830526}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addSphere({"center": {"x": 1.1560959815979004, "y": 3.1783061027526855, "z": 0.0080110002309083}, "radius": 0.28, "color": "#f5fafe", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("H7\n12.464",{"position": {"x": 1.1560959815979004, "y": 3.1783061027526855, "z": 0.0080110002309083}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addSphere({"center": {"x": 3.316226005554199, "y": 1.9700050354003906, "z": -0.0194339994341135}, "radius": 0.28, "color": "#08306b", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("H8\n12.465",{"position": {"x": 3.316226005554199, "y": 1.9700050354003906, "z": -0.0194339994341135}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addSphere({"center": {"x": 3.349802017211914, "y": -0.5050269961357117, "z": -0.0324800014495849}, "radius": 0.28, "color": "#4d99ca", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("H9\n12.465",{"position": {"x": 3.349802017211914, "y": -0.5050269961357117, "z": -0.0324800014495849}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addSphere({"center": {"x": 1.2232730388641355, "y": -1.7716989517211914, "z": -0.0181249994784593}, "radius": 0.28, "color": "#f7fbff", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("H10\n12.464",{"position": {"x": 1.2232730388641355, "y": -1.7716989517211914, "z": -0.0181249994784593}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addSphere({"center": {"x": -0.9368600249290466, "y": -0.5633959770202637, "z": 0.0093120001256465}, "radius": 0.28, "color": "#08316d", "opacity": 0.85});
# 	viewer_1770759970335668.addLabel("H11\n12.465",{"position": {"x": -0.9368600249290466, "y": -0.5633959770202637, "z": 0.0093120001256465}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970335668.addLabel("C: [1.157 \u2013 1.157]",{"fontSize": 11, "fontColor": "black", "backgroundColor": "white", "backgroundOpacity": 0.65, "screenOffset": {"x": -280, "y": -170}});
# 	viewer_1770759970335668.addLabel("H: [12.464 \u2013 12.465]",{"fontSize": 11, "fontColor": "black", "backgroundColor": "white", "backgroundOpacity": 0.65, "screenOffset": {"x": -280, "y": -152}});
# 	viewer_1770759970335668.zoomTo();
# viewer_1770759970335668.render();
# });
# </script>

# %%
print('Methane (all H equivalent):')
viz_methane.show_multi_element()
# Out:
# Methane (all H equivalent):
# <div id="3dmolviewer_1770759970346699"  style="position: relative; width: 800px; height: 550px;">
#         <p id="3dmolwarning_1770759970346699" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1770759970346699 = null;
# var warn = document.getElementById("3dmolwarning_1770759970346699");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1770759970346699 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1770759970346699"),{backgroundColor:"white"});
# viewer_1770759970346699.zoomTo();
# 	viewer_1770759970346699.addModel("5\n\nC      -0.012692      1.085799      0.008001\nH       0.002105     -0.003671      0.001993\nH       1.009511      1.462947      0.000290\nH      -0.539666      1.446744     -0.874730\nH      -0.522705      1.437165      0.904453","xyz");
# 	viewer_1770759970346699.setStyle({},{"stick": {"radius": 0.06, "color": "lightgrey"}});
# 	viewer_1770759970346699.addSphere({"center": {"x": -0.012691999785602, "y": 1.085798978805542, "z": 0.0080009996891021}, "radius": 0.28, "color": "#73c476", "opacity": 0.85});
# 	viewer_1770759970346699.addLabel("C0\n1.118",{"position": {"x": -0.012691999785602, "y": 1.085798978805542, "z": 0.0080009996891021}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970346699.addSphere({"center": {"x": 0.0021049999631941, "y": -0.003671000013127923, "z": 0.0019930000416934}, "radius": 0.28, "color": "#f7fbff", "opacity": 0.85});
# 	viewer_1770759970346699.addLabel("H1\n11.228",{"position": {"x": 0.0021049999631941, "y": -0.003671000013127923, "z": 0.0019930000416934}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970346699.addSphere({"center": {"x": 1.0095109939575195, "y": 1.4629470109939575, "z": 0.0002899999963119}, "radius": 0.28, "color": "#afd1e7", "opacity": 0.85});
# 	viewer_1770759970346699.addLabel("H2\n11.228",{"position": {"x": 1.0095109939575195, "y": 1.4629470109939575, "z": 0.0002899999963119}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970346699.addSphere({"center": {"x": -0.5396659970283508, "y": 1.4467439651489258, "z": -0.8747299909591675}, "radius": 0.28, "color": "#08306b", "opacity": 0.85});
# 	viewer_1770759970346699.addLabel("H3\n11.228",{"position": {"x": -0.5396659970283508, "y": 1.4467439651489258, "z": -0.8747299909591675}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970346699.addSphere({"center": {"x": -0.5227050185203552, "y": 1.4371650218963623, "z": 0.9044529795646667}, "radius": 0.28, "color": "#084387", "opacity": 0.85});
# 	viewer_1770759970346699.addLabel("H4\n11.228",{"position": {"x": -0.5227050185203552, "y": 1.4371650218963623, "z": 0.9044529795646667}, "fontSize": 10, "fontColor": "white", "backgroundColor": "black", "backgroundOpacity": 0.5, "alignment": "center"});
# 	viewer_1770759970346699.addLabel("C: [1.118 \u2013 1.118]",{"fontSize": 11, "fontColor": "black", "backgroundColor": "white", "backgroundOpacity": 0.65, "screenOffset": {"x": -280, "y": -170}});
# 	viewer_1770759970346699.addLabel("H: [11.228 \u2013 11.228]",{"fontSize": 11, "fontColor": "black", "backgroundColor": "white", "backgroundOpacity": 0.65, "screenOffset": {"x": -280, "y": -152}});
# 	viewer_1770759970346699.zoomTo();
# viewer_1770759970346699.render();
# });
# </script>

# %% [markdown]
# ## 6. Temperature dependence
#
# RPFR values are temperature-dependent. Available temperatures in qm9s.h5:
# `20, 60, 100, 140, 180, 220, 260, 273, 298, 300, 340, 380, 420 K`

# %%
from ipywidgets import interact, Dropdown

SMILES_MCC = 'COC(=O)NC(N)=O'   # Methyl carbamate

SMILES_benzene = 'c1ccccc1'   # Benzene

TEMPS = [20, 60, 100, 140, 180, 220, 260, 273, 298, 300, 340, 380, 420]
MODES = ['element_filter_H', 'multi_element', 'global_scale']

def show_at_temperature(temperature=300, mode='multi_element', element='H'):
    v = load_and_visualize(SMILES_MCC, temperature=float(temperature))
    if mode == 'element_filter_H':
        display(v.show_element_filter(element))
    elif mode == 'multi_element':
        display(v.show_multi_element())
    elif mode == 'global_scale':
        display(v.show_global_scale())

interact(
    show_at_temperature,
    temperature=Dropdown(options=TEMPS, value=300),
    mode=Dropdown(options=MODES, value='multi_element'),
    element=Dropdown(options=['H', 'C', 'N', 'O'], value='H'),
)
# Out:
# interactive(children=(Dropdown(description='temperature', index=9, options=(20, 60, 100, 140, 180, 220, 260, 2…
# <function __main__.show_at_temperature(temperature=300, mode='multi_element', element='H')>
