# %% [markdown]
# # Interactive RPFR Visualization
#
# Temperature and mode sweeps using ipywidgets.
#
# See `01_data_exploration.ipynb` for detailed explanations of each visualization mode.

# %% [markdown]
# ## Setup

# %%
import sys
from pathlib import Path
import numpy as np
import h5py
from ipywidgets import interact, Dropdown
from IPython.display import display

project_root = Path.cwd().parent.parent
sys.path.insert(0, str(project_root / 'src'))

from rpfr_gui.data import ChemistryResolver, H5Provider
from rpfr_gui.ui import RPFRVisualizer

H5_PATH  = Path('/Users/simonandren/QM9_H5/qm9s.h5')
IDX_PATH = project_root / 'data/processed/index.parquet'

resolver = ChemistryResolver(IDX_PATH)
provider = H5Provider(H5_PATH)

print('Libraries loaded OK')
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[4], line 17
#      14 H5_PATH  = Path('/Users/simonandren/QM9_H5/qm9s.h5')
#      15 IDX_PATH = project_root / 'data/processed/index.parquet'
# ---> 17 resolver = ChemistryResolver(IDX_PATH)
#      18 provider = H5Provider(H5_PATH)
#      20 print('Libraries loaded OK')
#
# File ~/Documents/isotope-informed-crn/src/rpfr_gui/data/chemistry_resolver.py:54, in ChemistryResolver.__init__(self, index_path, auto_generate)
#      51 self.lookup_table: pd.DataFrame | None = None
#      53 if self.index_path.exists():
# ---> 54     self._load_index()
#      55 elif not auto_generate:
#      56     # Silently allow missing index when auto_generate is False;
#      57     # the caller is expected to call build_index() later.
#      58     pass
#
# File ~/Documents/isotope-informed-crn/src/rpfr_gui/data/chemistry_resolver.py:68, in ChemistryResolver._load_index(self)
#      66 """Load the lookup index from disk."""
#      67 if self.index_path.suffix == ".parquet":
# ---> 68     self.lookup_table = pd.read_parquet(self.index_path)
#      69 elif self.index_path.suffix == ".csv":
#      70     # Read CSV with Molecule_ID as string type to preserve leading zeros
#      71     self.lookup_table = pd.read_csv(self.index_path, dtype={"Molecule_ID": str})
#
# File ~/Documents/isotope-informed-crn/.venv/lib/python3.11/site-packages/pandas/io/parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
#     673         columns=columns,
#    (...)    679         **kwargs,
#     680     )
#
# File ~/Documents/isotope-informed-crn/.venv/lib/python3.11/site-packages/pandas/io/parquet.py:64, in get_engine(engine)
#      62 for engine_class in engine_classes:
#      63     try:
# ---> 64         return engine_class()
#      65     except ImportError as err:
#      66         error_msgs += "\n - " + str(err)
#
# File ~/Documents/isotope-informed-crn/.venv/lib/python3.11/site-packages/pandas/io/parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File ~/Documents/isotope-informed-crn/.venv/lib/python3.11/site-packages/pandas/core/arrays/arrow/extension_types.py:174
#     167     pyarrow.register_extension_type(
#     168         ForbiddenExtensionType(pyarrow.null(), "arrow.py_extension_type")
#     169     )
#     171     pyarrow._hotfix_installed = True
# --> 174 patch_pyarrow()
#
# File ~/Documents/isotope-informed-crn/.venv/lib/python3.11/site-packages/pandas/core/arrays/arrow/extension_types.py:166, in patch_pyarrow()
#     157         pickletools.dis(serialized, out)
#     158         raise RuntimeError(
#     159             _ERROR_MSG.format(
#     160                 storage_type=storage_type,
#    (...)    163             )
#     164         )
# --> 166 pyarrow.unregister_extension_type("arrow.py_extension_type")
#     167 pyarrow.register_extension_type(
#     168     ForbiddenExtensionType(pyarrow.null(), "arrow.py_extension_type")
#     169 )
#     171 pyarrow._hotfix_installed = True
#
# File ~/Documents/isotope-informed-crn/.venv/lib/python3.11/site-packages/pyarrow/types.pxi:2280, in pyarrow.lib.unregister_extension_type()
#
# File ~/Documents/isotope-informed-crn/.venv/lib/python3.11/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowKeyError: No type extension with name arrow.py_extension_type found

# %%
def load_and_visualize(smiles, temperature=300.0):
    """Resolve SMILES and return an RPFRVisualizer."""
    mol_id = resolver.resolve(smiles, id_type='smiles')
    if mol_id is None:
        print(f'Not found: {smiles}')
        return None
    with h5py.File(H5_PATH, 'r') as f:
        g = f[mol_id]
        syms  = [s.decode() for s in g['Atom_Symbol'][()]]
        xyz   = np.stack([g['x'][()], g['y'][()], g['z'][()]], axis=1)
        rpfr  = g[f'RPFR_{int(temperature)}K'][()]
    print(f'{smiles} ({mol_id}) — {len(syms)} atoms')
    return RPFRVisualizer(smiles, syms, xyz, rpfr, temperature=temperature)

# %% [markdown]
# ## Molecule selector
#
# Compare different molecules interactively. Choose a molecule, temperature, visualization mode, and element filter.

# %%
MOLECULES = {
    'methyl carbamate': 'COC(=O)NC(N)=O',
    'benzene': 'c1ccccc1',
    'methane': 'C',
    'ethanol': 'CCO',
    'methanol': 'CO',
}
TEMPS = [20, 60, 100, 140, 180, 220, 260, 273, 298, 300, 340, 380, 420]
MODES = ['element_filter', 'multi_element']

@interact(
    molecule=Dropdown(options=list(MOLECULES.keys()), value='methyl carbamate'),
    temperature=Dropdown(options=TEMPS, value=300),
    mode=Dropdown(options=MODES, value='multi_element'),
    element=Dropdown(options=['H', 'C', 'N', 'O'], value='H'),
)
def show_molecule(molecule='methyl carbamate', temperature=300, mode='multi_element', element='H'):
    smiles = MOLECULES[molecule]
    v = load_and_visualize(smiles, temperature=float(temperature))
    if v is None:
        return
    if mode == 'element_filter':
        view = v.show_element_filter(element)
    elif mode == 'multi_element':
        view = v.show_multi_element()
    display(view)

# %% [markdown]
# ## Notes
#
# For custom SMILES, use `load_and_visualize(smiles, temperature)` directly in a code cell.
#
# See `01_data_exploration.ipynb` for static analysis and mode explanations.
